# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def dec_to_binary(d):
    bnr=np.binary_repr(d,8)
    return bnr

# %%
image=cv.imread("lena.tif",cv.IMREAD_GRAYSCALE)
plt.imshow(image,cmap='gray')
print(image)
# Out:
# [[137 136 133 ... 145 148 114]
#  [137 136 133 ... 145 148 114]
#  [138 133 134 ... 133 125  87]
#  ...
#  [ 28  28  29 ...  53  62  59]
#  [ 20  25  26 ...  64  69  65]
#  [ 22  30  25 ...  71  68  72]]

# %%
f = open("lena.txt", "a")
for row in image:
    for i in row:
        f.write(dec_to_binary(i)+"\n")    
f.close()
